# %%
import numpy as np
import pandas as pd

# %%
df=pd.read_csv(r'C:\Users\Student\Desktop\data1.csv')

# %%
pd.options.display.max_rows=10
# pd.set_option('display.max_rows',None)bara cancel kardan

# %%
df.head(3)
#.tail   az akhar hast
#.sample   random
# Out:
#           Car       Model  Volume  Weight  CO2
# 0      Toyoty        Aygo    1000     790   99
# 1  Mitsubishi  Space Star    1200    1160   95
# 2       Skoda      Citigo    1000     929   95

# %%
# df.to_string()

# %%
# df1=pd.read_json(r'C:\Users\Student\Desktop\data.json')
# df1

# %%
df.iloc[0,3]=np.nan
df.head()
# Out:
#           Car       Model  Volume  Weight  CO2
# 0      Toyoty        Aygo    1000     NaN   99
# 1  Mitsubishi  Space Star    1200  1160.0   95
# 2       Skoda      Citigo    1000   929.0   95
# 3        Fiat         500     900   865.0   90
# 4        Mini      Cooper    1500  1140.0  105

# %%
# df.dropna(inplace=True)
# df.head()

# %%
df['Weight'].fillna(round(df['Weight'].mean()),inplace=True)
df.head()
# Out:
#           Car       Model  Volume  Weight  CO2
# 0      Toyoty        Aygo    1000  1000.0   99
# 1  Mitsubishi  Space Star    1200  1160.0   95
# 2       Skoda      Citigo    1000   929.0   95
# 3        Fiat         500     900   865.0   90
# 4        Mini      Cooper    1500  1140.0  105
