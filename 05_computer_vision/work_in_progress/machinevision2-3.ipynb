# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt

# %%
image=cv2.imread(r"C:\Users\Student\Desktop\pic2\006.jpg")
new_image=np.zeros(image.shape,image.dtype)
alpha=float(input("Enter a alpha values"))
beta=int(input("enter beta values"))
new_image=cv2.convertScaleAbs(image,alpha=alpha,beta=beta)
plt.figure(figsize=[15,5])
plt.subplot(121);plt.imshow(image[...,::-1]);plt.title("original")
plt.subplot(122);plt.imshow(new_image[...,::-1]);plt.title("new_image")
plt.show()
#0.5,10
# Out:
# Enter a alpha values 0.5
# enter beta values 30

# %%
#how convertScaleAbs work
image=cv2.imread(r"C:\Users\Student\Desktop\pic2\006.jpg")
new_image2=np.zeros(image.shape,image.dtype)
alpha=float(input("Enter a alpha values"))
beta=int(input("enter beta values"))
for y in range(image.shape[0]):
    for x in range(iimage.shape[1]):
        for c in range(image.shape[2]):
# Out:
#   Cell In[8], line 9
#
#     ^
# SyntaxError: incomplete input

# %%
a=np.array([[1,3,6],[2,4,7]])
a.ravel()
# Out:
# array([1, 3, 6, 2, 4, 7])

# %%
gray_image=cv2.cvtColor(image,cv2.COLOR_BGR2GRAY)
gray_new_image=cv2.cvtColor(new_image,cv2.COLOR_BGR2GRAY)
gray_new_image2=cv2.cvtColor(new_image2,cv2.COLOR_BGR2GRAY)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[13], line 3
#       1 gray_image=cv2.cvtColor(image,cv2.COLOR_BGR2GRAY)
#       2 gray_new_image=cv2.cvtColor(new_image,cv2.COLOR_BGR2GRAY)
# ----> 3 gray_new_image2=cv2.cvtColor(new_image2,cv2.COLOR_BGR2GRAY)
#
# NameError: name 'new_image2' is not defined

# %%
#should find other misses codes in class recorded videos
plt.figure(figsize=[15,5])
plt.subplot(131);plt.hist(gray_image.ravel(),256,[0,256]);plt.title("original")
plt.subplot(131);plt.hist(gray_new_image.ravel(),256,[0,256]);plt.title("new_image1")
plt.subplot(131);plt.hist(graynew__image2.ravel(),256,[0,256]);plt.title("new_image2")
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[15], line 5
#       3 plt.subplot(131);plt.hist(gray_image.ravel(),256,[0,256]);plt.title("original")
#       4 plt.subplot(131);plt.hist(gray_new_image.ravel(),256,[0,256]);plt.title("new_image1")
# ----> 5 plt.subplot(131);plt.hist(graynew__image2.ravel(),256,[0,256]);plt.title("new_image2")
#       6 plt.show()
#
# NameError: name 'graynew__image2' is not defined

# %%
#notdone
