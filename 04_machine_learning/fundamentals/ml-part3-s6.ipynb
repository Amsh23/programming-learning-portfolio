# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.cluster import KMeans
from sklearn.preprocessing import StandardScaler
import warnings
warnings.filterwarnings("ignore")

# %%
df=pd.read_csv(r"C:\Users\Student\Desktop\customer.csv")
df.head()
# Out:
#    CustomerID  Gender  Age  Annual Income (k$)  Spending Score (1-100)
# 0           1    Male   19                  15                      39
# 1           2    Male   21                  15                      81
# 2           3  Female   20                  16                       6
# 3           4  Female   23                  16                      77
# 4           5  Female   31                  17                      40

# %%
df["Gender"].replace({"Male":1,"Female":2},inplace=True)
df.head()
# Out:
#    CustomerID  Gender  Age  Annual Income (k$)  Spending Score (1-100)
# 0           1       1   19                  15                      39
# 1           2       1   21                  15                      81
# 2           3       2   20                  16                       6
# 3           4       2   23                  16                      77
# 4           5       2   31                  17                      40

# %%
df.dtypes
# Out:
# CustomerID                int64
# Gender                    int64
# Age                       int64
# Annual Income (k$)        int64
# Spending Score (1-100)    int64
# dtype: object

# %%
df=df.set_index("CustomerID")
df.head()
# Out:
#             Gender  Age  Annual Income (k$)  Spending Score (1-100)
# CustomerID
# 1                1   19                  15                      39
# 2                1   21                  15                      81
# 3                2   20                  16                       6
# 4                2   23                  16                      77
# 5                2   31                  17                      40

# %%
df.isnull().sum()
# Out:
# Gender                    0
# Age                       0
# Annual Income (k$)        0
# Spending Score (1-100)    0
# dtype: int64

# %%
df.shape
# Out:
# (200, 4)

# %%
df.drop_duplicates(inplace=True)
df.shape
# Out:
# (200, 4)

# %%
x=np.array(df)
x
# Out:
# array([[  1,  19,  15,  39],
#        [  1,  21,  15,  81],
#        [  2,  20,  16,   6],
#        [  2,  23,  16,  77],
#        [  2,  31,  17,  40],
#        [  2,  22,  17,  76],
#        [  2,  35,  18,   6],
#        [  2,  23,  18,  94],
#        [  1,  64,  19,   3],
#        [  2,  30,  19,  72],
#        [  1,  67,  19,  14],
#        [  2,  35,  19,  99],
#        [  2,  58,  20,  15],
#        [  2,  24,  20,  77],
#        [  1,  37,  20,  13],
#        [  1,  22,  20,  79],
#        [  2,  35,  21,  35],
#        [  1,  20,  21,  66],
#        [  1,  52,  23,  29],
#        [  2,  35,  23,  98],
#        [  1,  35,  24,  35],
#        [  1,  25,  24,  73],
#        [  2,  46,  25,   5],
#        [  1,  31,  25,  73],
#        [  2,  54,  28,  14],
#        [  1,  29,  28,  82],
#        [  2,  45,  28,  32],
#        [  1,  35,  28,  61],
#        [  2,  40,  29,  31],
#        [  2,  23,  29,  87],
#        [  1,  60,  30,   4],
#        [  2,  21,  30,  73],
# ...

# %%
scaler=StandardScaler()
x_scale=scaler.fit_transform(x)
x_scale
# Out:
# array([[-1.12815215, -1.42456879, -1.73899919, -0.43480148],
#        [-1.12815215, -1.28103541, -1.73899919,  1.19570407],
#        [ 0.88640526, -1.3528021 , -1.70082976, -1.71591298],
#        [ 0.88640526, -1.13750203, -1.70082976,  1.04041783],
#        [ 0.88640526, -0.56336851, -1.66266033, -0.39597992],
#        [ 0.88640526, -1.20926872, -1.66266033,  1.00159627],
#        [ 0.88640526, -0.27630176, -1.62449091, -1.71591298],
#        [ 0.88640526, -1.13750203, -1.62449091,  1.70038436],
#        [-1.12815215,  1.80493225, -1.58632148, -1.83237767],
#        [ 0.88640526, -0.6351352 , -1.58632148,  0.84631002],
#        [-1.12815215,  2.02023231, -1.58632148, -1.4053405 ],
#        [ 0.88640526, -0.27630176, -1.58632148,  1.89449216],
#        [ 0.88640526,  1.37433211, -1.54815205, -1.36651894],
#        [ 0.88640526, -1.06573534, -1.54815205,  1.04041783],
#        [-1.12815215, -0.13276838, -1.54815205, -1.44416206],
# ...

# %%
plt.scatter(x_scale[:,1],x[:,3],marker=".")
plt.show()

# %%
#مثل فایل قبلی میشه تا حد زیادی بقیش چک کنم از روی فایلش باز

# %%
#کامل کنم یکسری خط های این مابین رو

# %%
labels=kmn.predict(x_scale)
set(labels)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[21], line 1
# ----> 1 labels=kmn.predict(x_scale)
#       2 set(labels)
#
# NameError: name 'kmn' is not defined

# %%
center=kmn.cluster_centers_
center
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[22], line 1
# ----> 1 center=kmn.cluster_centers_
#       2 center
#
# NameError: name 'kmn' is not defined

# %%
plt.scatter(x_scale[:,1]x_scale[:,3],c=labels)
plt.scatter(center[:,1],center[:,3],marker="x",s)
