# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt

# %%
img=cv2.imread(r"C:/Users/Student/Desktop/pic/transparency.png",cv2.IMREAD_UNCHANGED)
#شفافه زیرش

# %%
bgr_img=img[...,0:3]
alpha_image=img[...,-1]
rgb_img=cv2.cvtColor(bgr_img,cv2.COLOR_BGR2RGB)
plt.imshow(rgb_img);plt.title("RGB")
plt.show()

# %%
plt.imshow(alpha_image,cmap="gray");plt.title("RGB")
plt.show()

# %%
8
# Out:
#   Cell In[11], line 1
#     0\?22as
#       ^
# SyntaxError: unexpected character after line continuation character
