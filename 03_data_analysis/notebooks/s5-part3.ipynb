# %%
from scipy.stats import ttest_1samp
import numpy as np

# %%
height=[168,172,171,169,173,170,174]
tset, pval = ttest_1samp(height,170)
if pval < 0.05:
    print("we are rejecting null hypothesis")
else:
    print("we are accepting null hypothesis")
# Out:
# we are accepting null hypothesis

# %%
ages = np.genfromtxt(r"C:\Users\Student\Desktop\ages.csv")
tset, pval = ttest_1samp(ages,30)
print("p-values",pval)
if pval < 0.05:
    print("we are rejecting null hypothesis")
else:
    print("we are accepting null hypothesis")
# Out:
# p-values 0.5605155888171379
# we are accepting null hypothesis

# %%
from scipy.stats import ttest_ind
classA=[70,72,68,71,69]
classB=[75,78,74,77,78]
ttest,pval = ttest_ind(classA,classB)
if pval < 0.05:
    print("we are rejecting null hypothesis")
else:
    print("we are accepting null hypothesis")
print(ttest)
# Out:
# we are rejecting null hypothesis
# -5.942250821665665

# %%
week1 = np.genfromtxt(r"C:\Users\Student\Desktop\week1.csv", delimiter=",")
week2 = np.genfromtxt(r"C:\Users\Student\Desktop\week2.csv", delimiter=",")
ttest, pval = ttest_ind(week1,week2)
print("p-values",pval)
if pval < 0.05:
    print("we are rejecting null hypothesis")
else:
    print("we are accepting null hypothesis")
# Out:
# p-values 0.000676767690454633
# we are rejecting null hypothesis
# -3.510875818698744

# %%
import pandas as pd
from scipy import stats
df=pd.read_csv(r"C:\Users\Student\Desktop\blood_pressure.csv")
ttest,pval=stats.ttest_rel(df['bp_before'],df["bp_after"])
print(pval)
if pval < 0.05:
    print("we are rejecting null hypothesis")
else:
    print("we are accepting null hypothesis")
# Out:
# 0.0011297914644840823
# we are rejecting null hypothesis
