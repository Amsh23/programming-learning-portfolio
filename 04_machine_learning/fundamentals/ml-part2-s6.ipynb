# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.cluster import KMeans
from sklearn import datasets
import warnings
warnings.filterwarnings("ignore")

# %%
iris=datasets.load_iris()

# %%
x=iris.data

# %%
iris.feature_names
# Out:
# ['sepal length (cm)',
#  'sepal width (cm)',
#  'petal length (cm)',
#  'petal width (cm)']

# %%
iris.target_names
# Out:
# array(['setosa', 'versicolor', 'virginica'], dtype='<U10')

# %%
kmeans=KMeans()
#اینجاهارو یسری چک کنم ناکامل هستش

# %%
#خط های قبلش رو هم بزنم
set(labels)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[19], line 2
#       1 #خط های قبلش رو هم بزنم
# ----> 2 set(labels)
#
# NameError: name 'labels' is not defined

# %%
center=kmeans.cluster_centers_
center
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[20], line 1
# ----> 1 center=kmeans.cluster_centers_
#       2 center
#
# AttributeError: 'KMeans' object has no attribute 'cluster_centers_'

# %%
plt.scatter(x[:,0],x[:,1],c=labels)
plt.scatter(center[:,0],center[:,1],marker="x",s=150,c="red")
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[21], line 1
# ----> 1 plt.scatter(x[:,0],x[:,1],c=labels)
#       2 plt.scatter(center[:,0],center[:,1],marker="x",s=150,c="red")
#       3 plt.show()
#
# NameError: name 'labels' is not defined

# %%
y=[]
for k in range(1,6):
    kmeans=KMeans(n_clusters=k)
    kmn.fot(x)
    y.append(kmn.inertia)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[23], line 4
#       2 for k in range(1,6):
#       3     kmeans=KMeans(n_clusters=k)
# ----> 4     kmn.fot(x)
#       5     y.append(kmn.inertia)
#
# NameError: name 'kmn' is not defined

# %%
mylist=[#عددها مثل فایل استاد

]
dis=[]
for i in range(len(mylist)-1):
    d=mylist[i]-mylist[i+1]
    dis.append(d)
print(dis)
# Out:
# []

# %%
plt.plot(np.arange(1,6),y,"o-")
plt.xlabel("number of cluster")
plt.ylabel("inertia")
plt.show()
"""برای اینکه با توجه به مقدار تفاضل اعداد و کمتر بودنش 
فاصلش بفهمیم کدوم نقطه بهتره که سومی بهتر شد اینج"""
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[28], line 1
# ----> 1 plt.plot(np.arange(1,6),y,"o-")
#       2 plt.xlabel("number of cluster")
#       3 plt.ylabel("inertia")
#
# File ~\anaconda3\Lib\site-packages\matplotlib\pyplot.py:3590, in plot(scalex, scaley, data, *args, **kwargs)
#    3582 @_copy_docstring_and_deprecators(Axes.plot)
#    3583 def plot(
#    3584     *args: float | ArrayLike | str,
#    (...)
#    3588     **kwargs,
#    3589 ) -> list[Line2D]:
# -> 3590     return gca().plot(
#    3591         *args,
#    3592         scalex=scalex,
#    3593         scaley=scaley,
#    3594         **({"data": data} if data is not None else {}),
#    3595         **kwargs,
#    3596     )
#
# File ~\anaconda3\Lib\site-packages\matplotlib\axes\_axes.py:1724, in Axes.plot(self, scalex, scaley, data, *args, **kwargs)
#    1481 """
# ...

# %%
#یکسری خط های بالاشو عقب افتادم اونارو باید بنویسم تا جواب بده اینا
clusters=pd.DataFrame(x.copy())
clusters["cluster_prediction"]=kmeans.fit_predict(x)
clusters.sample(10)
# Out:
#        0    1    2    3  cluster_prediction
# 99   5.7  2.8  4.1  1.3                   0
# 6    4.6  3.4  1.4  0.3                   0
# 10   5.4  3.7  1.5  0.2                   0
# 82   5.8  2.7  3.9  1.2                   0
# 86   6.7  3.1  4.7  1.5                   0
# 39   5.1  3.4  1.5  0.2                   0
# 63   6.1  2.9  4.7  1.4                   0
# 3    4.6  3.1  1.5  0.2                   0
# 52   6.9  3.1  4.9  1.5                   0
# 125  7.2  3.2  6.0  1.8                   0

# %%
iris.target_names
# Out:
# array(['setosa', 'versicolor', 'virginica'], dtype='<U10')

# %%
fig,ax=plt.subplots(figsize=(15,7))
plt.scatter(x=clusters[clusters["cluster_prediction"]==0][0],
           y=clusters[clusters["cluster_prediction"]==0][1],s=70,edgecolors="teal",lw=0.3,c="teal",label="setosa")

plt.scatter(x=clusters[clusters["cluster_prediction"]==1][0],
           y=clusters[clusters["cluster_prediction"]==1][1],s=70,edgecolors="lime",lw=0.3,c="lime",label="veisicolor")

plt.scatter(x=clusters[clusters["cluster_prediction"]==0][0],
           y=clusters[clusters["cluster_prediction"]==0][1],s=70,edgecolors="magenta",lw=0.3,c="magenta",label="virginica")

plt.scatter(x=center[:,0],y=center[:,1],c="y",label="center",edgecolors="k",lw=0.3)
plt.legend(loc="upper right")
plt.xlim(4,8)
plt.ylim(1.8,4.5)
ax.set_ylabel("sepal width (cm)")
ax.set_xlabel("sepal length (cm)")
plt.title("iris")
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[35], line 11
#       5 plt.scatter(x=clusters[clusters["cluster_prediction"]==1][0],
#       6            y=clusters[clusters["cluster_prediction"]==1][1],s=70,edgecolors="lime",lw=0.3,c="lime",label="veisicolor")
#       8 plt.scatter(x=clusters[clusters["cluster_prediction"]==0][0],
#       9            y=clusters[clusters["cluster_prediction"]==0][1],s=70,edgecolors="magenta",lw=0.3,c="magenta",label="virginica")
# ---> 11 plt.scatter(x=center[:,0],y=center[:,1],c="y",label="center",edgecolors="k",lw=0.3)
#      12 plt.legend(loc="upper right")
#      13 plt.xlim(4,8)
#
# NameError: name 'center' is not defined

# %%
y=iris.target
data=datasets.load_iris()
list(data.target_names)
pd.crosstab(y,labels)

#pd.crosstab(iris.target,labels)
#این دیگه نمیخواد سه تا خط بالاییشو بنویسی
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[39], line 4
#       2 data=datasets.load_iris()
#       3 list(data.target_names)
# ----> 4 pd.crosstab(y,labels)
#
# NameError: name 'labels' is not defined

# %%
#بعنوان تمرین چک کنیم ببینیم تعدادشون چقدر متفاوته صفر و یک ها مثلا با چیز واقعی و پیش بینیش
