# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.cluster.hierarchy import dendrogram,linkage,fcluster
from sklearn.datasets import load_iris
from sklearn.datasets import make_blobs
from sklearn.cluster import AgglomerativeClustering

# %%
iris=datasets.load_iris()
x=iris.data

# %%
hirarchical=linkage(x,method="complete")
dendrogram(hirarchical)
plt.show()

# %%
labels=fcluster(hirarchical,3,criterion="distance")
set(labels)
# Out:
# {1, 2, 3, 4}

# %%
plt.scatter(x[:,0],x[:,1],c=labels)
plt.show()

# %%
x,y=make_blobs(n_samples=50,centers=[[4,4],[-2,-1],[1,1],[10,4]],cluster_std=0.9)
print(x.shape)
print(y.shape)
# Out:
# (50, 2)
# (50,)

# %%
plt.scatter(x[:,0],x[:,1],marker="o")
plt.show()

# %%
agglom=AgglomerativeClustering(n_clusters=4,linkage="average")
agglom.fit(x,y)
# Out:
# AgglomerativeClustering(linkage='average', n_clusters=4)

# %%
plt.figure(figsize=(6,4))
x_min,x_max=np.min(x,axis=0),np.max(x,axis=0)
x=(x-x_min)/(x_max-x_min)
for i in range(x.shape[0]):
    plt.text(x[i,0],x[i,1],str(y[i]),color=plt.cm.nipy_spectral(agglom.labels_[i]/10),fontdict={"weight":"bold","size":9})
plt.xticks([])
plt.yticks([])
plt.scatter(x[:,0],x[:,1],marker=".")
plt.show()

# %%
#این رو استاد روی یه فایل خودش زد
from sklearn.cluster import DBSCAN
