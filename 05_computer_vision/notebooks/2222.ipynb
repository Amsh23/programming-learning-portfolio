# %%
import numpy as np
import matplotlib.pyplot as plt
import cv2

# %%
img_fn=[r"C:\Users\Student\Desktop\pic08\a1.png", r"C:\Users\Student\Desktop\pic08\a2.png" 
        , r"C:\Users\Student\Desktop\pic08\a3.png" , r"C:\Users\Student\Desktop\pic08\a4.png"]
img_list=[cv2.imread(fn) for fn in img_fn]
exposure_times=np.array([15.0, 2.5, 0.25, 0.333], dtype=np.float32)

plt.figure(figsize=[18,4])
for i, (image,exposure) in enumerate(zip(img_list, exposure_times)):
    plt.subplot(1,4,i+1);plt.imshow(image[...,::-1]);plt.title(exposure);plt.xticks([]);plt.yticks
