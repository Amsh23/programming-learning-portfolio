# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split

# %%
df=pd.read_csv(r"C:\Users\Student\Desktop\boston.csv")
df.head()
# Out:
#    Unnamed: 0     crim    zn  indus  chas    nox     rm   age     dis  rad  \
# 0           1  0.00632  18.0   2.31     0  0.538  6.575  65.2  4.0900    1
# 1           2  0.02731   0.0   7.07     0  0.469  6.421  78.9  4.9671    2
# 2           3  0.02729   0.0   7.07     0  0.469  7.185  61.1  4.9671    2
# 3           4  0.03237   0.0   2.18     0  0.458  6.998  45.8  6.0622    3
# 4           5  0.06905   0.0   2.18     0  0.458  7.147  54.2  6.0622    3
#
#    tax  ptratio   black  lstat  medv
# 0  296     15.3  396.90   4.98  24.0
# 1  242     17.8  396.90   9.14  21.6
# 2  242     17.8  392.83   4.03  34.7
# 3  222     18.7  394.63   2.94  33.4
# 4  222     18.7  396.90   5.33  36.2

# %%
df.drop(["Unnamed: 0"],axis=1,inplace=True)
df.head()
# Out:
#       crim    zn  indus  chas    nox     rm   age     dis  rad  tax  ptratio  \
# 0  0.00632  18.0   2.31     0  0.538  6.575  65.2  4.0900    1  296     15.3
# 1  0.02731   0.0   7.07     0  0.469  6.421  78.9  4.9671    2  242     17.8
# 2  0.02729   0.0   7.07     0  0.469  7.185  61.1  4.9671    2  242     17.8
# 3  0.03237   0.0   2.18     0  0.458  6.998  45.8  6.0622    3  222     18.7
# 4  0.06905   0.0   2.18     0  0.458  7.147  54.2  6.0622    3  222     18.7
#
#     black  lstat  medv
# 0  396.90   4.98  24.0
# 1  396.90   9.14  21.6
# 2  392.83   4.03  34.7
# 3  394.63   2.94  33.4
# 4  396.90   5.33  36.2

# %%
x=df.iloc[:,:-1].values
y=df.iloc[:,-1].values

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=30)

# %%
model=LinearRegression()
model.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
y_pred=model.predict(x_test)

# %%
model.predict([[0.08829,12.5,7.87,0,0.524,6.012,66.6,5.5605,5,311,15.2,395.6,12.43]])
# Out:
# array([22.87544163])

# %%
from sklearn.preprocessing import StandardScaler

# %%
from sklearn.metrics import mean_absolute_error,mean_squared_error,r2_score

# %%
x=df.iloc[:,:-1].values
y=df.iloc[:,-1].values
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=30)
scaler=StandardScaler()
x_train_scale=scaler.fit_transform(x_train)
x_test_scale=scaler.fit_transform(x_test)

model=LinearRegression()
model.fit(x_train,y_train)
y_pred=model.predict(x_test)
sample=[[0.08829,12.5,7.87,0,0.524,6.012,66.6,5.5605,5,311,15.2,395.6,12.43]]
sample_scale=scaler.fit_transform(sample)
model.predict(sample_scale)
# Out:
# array([39.0845885])

# %%
mse=mean_squared_error(y_test,y_pred)
mse
# Out:
# 17.93304218869928

# %%
mae=mean_absolute_error(y_test,y_pred)
mae
# Out:
# 3.2254104069763407

# %%
r2=r2_score(y_test,y_pred)
r2
#above 70% is good for ml
# Out:
# -25.431032122882524

# %%
newx=x[:,[3,5]]
newy=y

# %%
x_train,x_test,y_train,y_test=train_test_split(newx,newy,test_size=0.2,random_state=30)
scaler=StandardScaler()
x_train_scale=scaler.fit_transform(x_train)
x_test_scale=scaler.fit_transform(x_test)

model=LinearRegression()
model.fit(x_train_scale,y_train)
y_pred=model.predict(x_test)
sample=[[1,4]]
sample_scale=scaler.fit_transform(sample)
model.predict(sample_scale)
# Out:
# array([22.53762376])

# %%
mae=mean_absolute_error(y_test,y_pred)
mae
# Out:
# 40.597947927490125

# %%
mse=mean_squared_error(y_test,y_pred)
mse
# Out:
# 1681.51137156334

# %%
r2=r2_score(y_test,y_pred)
r2
# Out:
# -25.431032122882524
