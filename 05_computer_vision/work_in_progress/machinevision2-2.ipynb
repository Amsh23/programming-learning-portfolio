# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt

# %%
image=cv2.imread(r"C:\Users\Student\Desktop\pic2\006.jpg")

# %%
M=np.ones(image.shape,dtype="uint8")*50
#matrix

added=cv2.add(image,M)
subtracted=cv2.subtract(image,M)

# %%
plt.figure(figsize=[15,5])
plt.subplot(131);plt.imshow(image[...,::-1]);plt.title("original")
plt.subplot(132);plt.imshow(added[...,::-1]);plt.title("added")
plt.subplot(133);plt.imshow(subtracted[...,::-1]);plt.title("subtracted")
plt.show()

# %%
img2=cv2.imread(r"C:\Users\Student\Desktop\pic2\x.jpg")
plt.subplot(121)
plt.imshow(img2[...,::-1])
plt.subplot(122)
img3=cv2.imread(r"C:\Users\Student\Desktop\pic2\x.jpg")[100:200,300:400]
plt.imshow(img3[...,::-1])
plt.show()

# %%
img1=cv2.imread(r"C:\Users\Student\Desktop\pic2\c.jpg")
shape=img1.shape
print(shape)
img2=cv2.imread(r"C:\Users\Student\Desktop\pic2\x.jpg")[300:300+shape[0],400:400+shape[1],:]
output=cv2.add(img2,img1)
plt.figure(figsize=[15,5])
plt.subplot(131);plt.imshow(img1[...,::-1]);plt.title("img1")
plt.subplot(132);plt.imshow(img2[...,::-1]);plt.title("img2")
plt.subplot(133);plt.imshow(output[...,::-1]);plt.title("output")
plt.show()
# Out:
# (150, 300, 3)

# %%
img1=cv2.imread(r"C:\Users\Student\Desktop\pic2\x.jpg")
img2=cv2.imread(r"C:\Users\Student\Desktop\pic2\c.jpg")

logo_h,logo_w,_=img2.shape
location_h=100
location_w=200
padded_img2=np.zeros_like(img1)
padded_img2[location_h:location_h+logo_h,location_w:location_w+logo_w,:]=img2
plt.imshow(padded_img2[...,::-1])
plt.show()

# %%
output=cv2.add(img1,padded_img2)
plt.imshow(output[...,::-1])

# %%
img1=cv2.imread(r"C:\Users\Student\Desktop\pic2\opencv.jpg")
img2=cv2.imread(r"C:\Users\Student\Desktop\pic2\c.jpg")
output=cv2.addWeighted(img1,0.2,img2,0.8,0) #x+y=should be 1
plt.figure(figsize=[15,5])
plt.subplot(131);plt.imshow(img1[...,::-1]);plt.title("img1")
plt.subplot(132);plt.imshow(img2[...,::-1]);plt.title("img2")
plt.subplot(133);plt.imshow(output[...,::-1]);plt.title("output")
plt.show()
